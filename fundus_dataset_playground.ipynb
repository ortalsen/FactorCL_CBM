# %%
import pandas as pd

# %%
df = pd.read_csv('~/data/Fundus/JustRAIGS_Train_labels.csv', delimiter=';')

# %%
# I want to calculate sum of each row but only over certain columns
df['sum_concepts'] = df.iloc[:, 7:].sum(axis=1)

# %%
df[df['sum_concepts']>0].shape
# Out:
# (6670, 38)

# %%
df.columns
# Out:
# Index(['Eye ID', 'Final Label', 'Fellow Eye ID', 'Age', 'Label G1', 'Label G2',
#        'Label G3', 'G1 ANRS', 'G1 ANRI', 'G1 RNFLDS', 'G1 RNFLDI', 'G1 BCLVS',
#        'G1 BCLVI', 'G1 NVT', 'G1 DH', 'G1 LD', 'G1 LC', 'G2 ANRS', 'G2 ANRI',
#        'G2 RNFLDS', 'G2 RNFLDI', 'G2 BCLVS', 'G2 BCLVI', 'G2 NVT', 'G2 DH',
#        'G2 LD', 'G2 LC', 'G3 ANRS', 'G3 ANRI', 'G3 RNFLDS', 'G3 RNFLDI',
#        'G3 BCLVS', 'G3 BCLVI', 'G3 NVT', 'G3 DH', 'G3 LD', 'G3 LC',
#        'sum_concepts'],
#       dtype='object')

# %%
# I want to select only rows where Final Label is RG and sum_concepts is greater than 0
df[(df['Final Label']=='NRG') & (df['sum_concepts']>0)]
# Out:
#              Eye ID Final Label Fellow Eye ID   Age Label G1 Label G2  \
# 11      TRAIN000011         NRG   TRAIN061398  50.0       RG      NRG
# 57      TRAIN000057         NRG   TRAIN018238  53.0       RG      NRG
# 74      TRAIN000074         NRG   TRAIN051293  45.0       RG      NRG
# 75      TRAIN000075         NRG   TRAIN049541  42.0       RG      NRG
# 99      TRAIN000099         NRG   TRAIN068167  65.0       RG      NRG
# ...             ...         ...           ...   ...      ...      ...
# 101369  TRAIN101388         NRG   TRAIN009691  63.0      NRG       RG
# 101370  TRAIN101389         NRG   TRAIN068534  57.0       RG      NRG
# 101390  TRAIN101409         NRG   TRAIN069678  54.0       RG        U
# 101397  TRAIN101416         NRG   TRAIN068490  68.0      NRG       RG
# 101405  TRAIN101424         NRG   TRAIN035938  56.0       RG      NRG
#
#        Label G3  G1 ANRS  G1 ANRI  G1 RNFLDS  ...  G3 ANRI  G3 RNFLDS  \
# ...

# %%
# I want to count non-zeros values in each column ignore NaN

df[df['Final Label']=='RG'].iloc[:, 7:].fillna(0).astype(bool).sum(axis=0)
# Out:
# G1 ANRS         1952
# G1 ANRI         2166
# G1 RNFLDS        390
# G1 RNFLDI        472
# G1 BCLVS         625
# G1 BCLVI         684
# G1 NVT          1138
# G1 DH             99
# G1 LD           1026
# G1 LC           1453
# G2 ANRS         1831
# G2 ANRI         1986
# G2 RNFLDS        274
# G2 RNFLDI        348
# G2 BCLVS         565
# G2 BCLVI         674
# G2 NVT           739
# G2 DH             89
# G2 LD            987
# G2 LC           1116
# G3 ANRS          637
# G3 ANRI          707
# G3 RNFLDS         93
# G3 RNFLDI        111
# G3 BCLVS         180
# G3 BCLVI         149
# G3 NVT           173
# G3 DH             31
# G3 LD            366
# G3 LC            522
# sum_concepts    3270
# dtype: int64

# %%
df[(df['Final Label']=='RG') & (df['G1 ANRS']>0.0)]
# Out:
#              Eye ID Final Label Fellow Eye ID   Age Label G1 Label G2  \
# 34      TRAIN000034          RG           NaN  32.0       RG       RG
# 60      TRAIN000060          RG           NaN  74.0       RG       RG
# 68      TRAIN000068          RG   TRAIN012581  64.0       RG      NRG
# 100     TRAIN000100          RG           NaN  77.0       RG      NRG
# 106     TRAIN000106          RG   TRAIN014144  81.0       RG       RG
# ...             ...         ...           ...   ...      ...      ...
# 101097  TRAIN101116          RG   TRAIN037937  84.0       RG       RG
# 101204  TRAIN101223          RG   TRAIN067820  61.0       RG       RG
# 101296  TRAIN101315          RG   TRAIN032604  55.0       RG       RG
# 101339  TRAIN101358          RG   TRAIN008388  84.0       RG       RG
# 101349  TRAIN101368          RG   TRAIN016577  74.0       RG       RG
#
#        Label G3  G1 ANRS  G1 ANRI  G1 RNFLDS  ...  G3 ANRI  G3 RNFLDS  \
# ...

# %%
3720/df.shape[0]
# Out:
# 0.03667807104897311
